# %% [markdown]
# # TP2 - Sistemas inteligentes
# ## Clasificacion de tumores de piel mediante el uso de una Red Neuronal Artificial Backpropagation

# %%
#@title Librerías a usar
from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from sklearn.model_selection import train_test_split

from keras.utils import to_categorical

import tensorflow as tf
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import os

import random

import cv2
from PIL import Image

from  sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

import ipywidgets as widgets
from ipywidgets import Box, Layout
import random

print("Librerías cargadas")
# Out:
# Librerías cargadas

# %% [markdown]
# ##Imágenes:

# %%
#@title Acceder al Drive

from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

# directorio local en Google Drive
path = 'gdrive/My Drive/data/' #@param {type:"string"}
path_entrenamiento = 'train'  #@param {type:"string"}
path_prueba = 'test'  #@param {type:"string"}

imagPath_train = path + path_entrenamiento
imagPath_test = path + path_prueba
# Out:
# Mounted at /content/gdrive

# %%
#@title Cargar imágenes

#@markdown ### Parámetros para imágenes:
imagen_ancho =  32#@param {type:"integer"}
imagen_largo =  32#@param {type:"integer"}
imagen_color = True #@param {type:"boolean"}

# tamaño de las imágenes
if imagen_ancho<=10:
  imagen_largo = 10
if imagen_largo<=10:
  imagen_largo = 10
IMAGE_SHAPE = (imagen_ancho, imagen_largo, (3 if imagen_color else 1))

# define función para cargar las imágenes
def cargarImagenes(imagPath):
  classes_ori = []
  images_ori = []

  all_dirs = os.listdir( imagPath )
  for each_dir in all_dirs:

      auxiPath = imagPath + '/' + each_dir
      imagFN  = os.listdir( auxiPath )
      for each_imagFN in imagFN:


            # abre la imagen
            imag = Image.open(auxiPath + "/" + each_imagFN)

            # ajusta el tamaño
            if IMAGE_SHAPE[2]==1:
              tipoImage = 'L'
            else:
              tipoImage = 'RGB'
            imag = imag.convert(tipoImage)
            imag = imag.resize((IMAGE_SHAPE[0], IMAGE_SHAPE[1]), Image.LANCZOS)

            # transforma a un vector de nros
            arImag = np.array(imag)

            # agrega a los vectores
            classes_ori.append( each_dir )
            images_ori.append( arImag )

  return classes_ori, images_ori, tipoImage

# carga las imagenes de entrenamiento
classes_train, images_train, tipoImage_train = cargarImagenes(imagPath_train)
print("> Para Entrenamiento: ")
print("- Clases cargadas: ", len(np.unique(classes_train)))
print("- Imágenes cargadas: ", len(classes_train))

if len(classes_train)>0:
  print("- Ejemplo ", classes_train[0], " ", images_train[0].shape, ": ")
  display( Image.fromarray(images_train[0], tipoImage_train) )

# carga las imagenes de prueba
classes_test, images_test, tipoImage_test = cargarImagenes(imagPath_test)
print("\n\n> Para Prueba: ")
print("- Clases cargadas: ", len(np.unique(classes_test)))
print("- Imágenes cargadas: ", len(images_test))

if len(classes_test)>0:
  print("- Ejemplo ", classes_test[0], " ", images_test[0].shape, ": ")
  display( Image.fromarray(images_test[0], tipoImage_test) )
# Out:
# > Para Entrenamiento:
# - Clases cargadas:  2
# - Imágenes cargadas:  2837
# - Ejemplo  malignant   (32, 32, 3) :
# <PIL.Image.Image image mode=RGB size=32x32>
# > Para Prueba:
# - Clases cargadas:  2
# - Imágenes cargadas:  460
# - Ejemplo  malignant   (32, 32, 3) :
# <PIL.Image.Image image mode=RGB size=32x32>

# %%
#@title Preparar imágenes para usar en el modelo

# define función auxiliar para mostrar imágenes preparadas
def plot_image(imag):
  if IMAGE_SHAPE[2]==1:
    plt.imshow((imag).reshape(IMAGE_SHAPE[0], IMAGE_SHAPE[1]).astype(np.uint8)) ## *255
    plt.gray()
  else:
    plt.imshow((imag).reshape(IMAGE_SHAPE).astype(np.uint8)) ## *255
  plt.axis("off")

# define función auxiliar para preparar la lista de imágenes a procesar
def prepare_imageList(imagList):
##  auxiAr = np.array(imagList).astype('float32') / 255.
##  auxiAr = auxiAr.reshape((len(auxiAr), num_inputs))
  auxiAr = np.array(imagList)
  auxiAr = auxiAr.reshape((len(auxiAr), IMAGE_SHAPE[0], IMAGE_SHAPE[1], IMAGE_SHAPE[2]))
  return auxiAr

  return np.array(auxiAr)

# define función auxiliar para preparar lista de clases
def prepare_clasesList(classesList, dictMapeo=None):
  if dictMapeo==None:
    # genera diccionario de mapeo
    auxDict = list(set(classesList))
    dictMapeo = dict( zip( auxDict, range(len(auxDict)) ) )
  # realiza el mapeo
  y = []
  for cl in classesList:
      y.append( dictMapeo[cl] )
  # convierte valores numéricos a columnas de vakores binarios (i.e. one hot encoded)
  dummy_y = to_categorical(y)
  # devuelve
  return np.array(y), np.array(dummy_y), dictMapeo

# define vector auxiliar de datos de entrada para usar en el entrenamiento y prueba
x_train = prepare_imageList(images_train)
x_test = prepare_imageList(images_test)

# define vector auxiliar de datos de salida para usar en el entrenamiento y prueba
# también usa esta información para determinar la cantida de neuronas de salida
y_train, y_trainEnc, dictMapeo = prepare_clasesList(classes_train)
y_test, y_testEnc,_ = prepare_clasesList(classes_test, dictMapeo)

daLayers_modelo = []

# genera diccionario auxiliar para poder convertir de ID de clase a nombre de clase
clases_map = [ x for x,y in dictMapeo.items() ]

print("> Para Entrenamiento: ")
print(" - x_train (cant ejemplos, datos entrada): ", x_train.shape)
print(" - y_trainEnc (cant): ", len(y_trainEnc))
print(" - y_train (cant): ", len(y_train))
print("\n\n> Para Prueba: ")
print(" - x_test (cant ejemplos, datos entrada): ", x_test.shape)
print(" - y_testEnc (cant): ", len(y_testEnc))
print(" - y_test (cant): ", len(y_test))
print("\n\n> Para Ambos: ")
print(" - dictMapeo: ", dictMapeo)
print(" - clases_map: ", clases_map)
if len(y_train)>0:
  print("\n - Imagen reconstruida de ", clases_map[y_train[0]],  "(", y_train[0], " / ", y_trainEnc[0], ")")
  plot_image(x_train[0])
# Out:
# > Para Entrenamiento:
#  - x_train (cant ejemplos, datos entrada):  (2837, 32, 32, 3)
#  - y_trainEnc (cant):  2837
#  - y_train (cant):  2837
#
#
# > Para Prueba:
#  - x_test (cant ejemplos, datos entrada):  (460, 32, 32, 3)
#  - y_testEnc (cant):  460
#  - y_test (cant):  460
#
#
# > Para Ambos:
#  - dictMapeo:  {'benign': 0, 'malignant': 1}
#  - clases_map:  ['benign', 'malignant']
#
#  - Imagen reconstruida de  malignant ( 1  /  [0. 1.] )

# %% [markdown]
# ##Modelo:

# %%
#@title Establecer capas de Image Augmentation (opcional)

aplicar_da_preProcesamiento = False #@param {type:"boolean"}

#@markdown Nota: estas capas se agregan al modelo para generar automaticamente data augmentation sólo durante el entrenamiento.
da_preProcesamiento_RandomFlip_Horizontal = False #@param {type:"boolean"}
da_preProcesamiento_RandomFlip_Vertical = False #@param {type:"boolean"}
da_preProcesamiento_RandomTranslation_Horizontal_factor = 0.4 #@param {type:"number"}
da_preProcesamiento_RandomTranslation_Vertical_factor = 0.4 #@param {type:"number"}
da_preProcesamiento_RandomRotation_factor = 0.4 #@param {type:"number"}
da_preProcesamiento_RandomZoom_factor = 0.4 #@param {type:"number"}
da_preProcesamiento_RandomContrast_factor = 0.4 #@param {type:"number"}
da_preProcesamiento_RandomBrightness_factor = 0.4 #@param {type:"number"}

daLayers_modelo = []

# capas de data augmentation (solo para training)
if aplicar_da_preProcesamiento:

  if da_preProcesamiento_RandomFlip_Horizontal or da_preProcesamiento_RandomFlip_Vertical:
      if da_preProcesamiento_RandomFlip_Horizontal:
        modeDAFlip = "horizontal"
        if da_preProcesamiento_RandomFlip_Vertical:
          modeDAFlip = modeDAFlip + "_and_vertical"
      else:
        modeDAFlip = "vertical"
      daLayers_modelo.append( tf.keras.layers.RandomFlip(mode=modeDAFlip, seed=None, name="da_rndFlip_"+modeDAFlip) )

  if (da_preProcesamiento_RandomTranslation_Horizontal_factor != 0.0) or (da_preProcesamiento_RandomTranslation_Vertical_factor != 0.0):
    daLayers_modelo.append( tf.keras.layers.RandomTranslation(height_factor=da_preProcesamiento_RandomTranslation_Vertical_factor/100, width_factor=da_preProcesamiento_RandomTranslation_Horizontal_factor, name="da_rndTranslation", fill_mode="nearest") )

  if da_preProcesamiento_RandomRotation_factor != 0.0:
      daLayers_modelo.append( tf.keras.layers.RandomRotation(factor=da_preProcesamiento_RandomRotation_factor, name="da_rndRotation", fill_mode="nearest") )

  if da_preProcesamiento_RandomZoom_factor != 0.0:
    daLayers_modelo.append( tf.keras.layers.RandomZoom(height_factor=da_preProcesamiento_RandomZoom_factor, name="da_rndZoom", fill_mode="nearest") )

  if da_preProcesamiento_RandomContrast_factor != 0.0:
    daLayers_modelo.append( tf.keras.layers.RandomContrast(factor=da_preProcesamiento_RandomContrast_factor, name="da_rndContrast") )

  if da_preProcesamiento_RandomBrightness_factor != 0.0:
    daLayers_modelo.append( tf.keras.layers.RandomBrightness(factor=da_preProcesamiento_RandomBrightness_factor, name="da_rndBrightness") )

# Visualize images and augmentations
cantCapasDA = len(daLayers_modelo) + 2
if cantCapasDA <= 2:
  print("No se aplican capas de Image Augmentation.")
else:
  print("Ejemplo de posibles aplicaciones:")
  fig, ax = plt.subplots(cantCapasDA, 5, figsize=(15,cantCapasDA*3))

  j = 0
  for j in range(5):

    # toma al azar las imágenes a mostrar
    posIm = random.randint(1, len(x_train))
    im = x_train[posIm-1]

    # muestra imagen original
    ax[0][j].imshow((im.astype("uint8")))
    if j == 0:
      ax[0][j].set_title("original")
    ax[0][j].axis('off')

    # muestra imagen con aplicación de capa
    i = 1
    for da_lay in daLayers_modelo:
            ax[i][j].imshow(da_lay(im).numpy().astype("uint8"))
            if j == 0:
              ax[i][j].set_title("sólo capa " + da_lay.name)
            ax[i][j].axis('off')
            i = i + 1

    # aplica todas las capas
    for da_lay in daLayers_modelo:
        im = da_lay(im)

    ax[i][j].imshow(im.numpy().astype("uint8"))
    if j == 0:
      ax[i][j].set_title("TODAS LAS CAPAS")
    ax[i][j].axis('off')

    j = j + 1

  plt.show()
# Out:
# No se aplican capas de Image Augmentation.

# %%
#@title Establecer modelo

#@markdown ### Parámetros de la Red:
rna_cant_neuronas_capas_ocultas = '512, 256' #@param {type:"string"}
lineal_tipo_funcion = 'relu' #@param ['exponential', 'linear', 'relu', 'sigmoid', 'tanh' ]
#markdown (Nota: se puede indicar Cantidad de neuronas, D para DropOut, BN para BatchNormalization)
rna_porc_capa_DropOut = 0.2 #@param {type:"number"}

rna_tipo_capa_salida = 'softmax-MultiClase' #@param ["lineal-Numero", "softmax-MultiClase"]

#@markdown ### Parámetros del Optimizador:
opt_tipo = "Adam" #@param ["Gradiente Decreciente", "Adam", "Adadelta", "Adagrad", "Adamax", "Nadam", "FTRL"]
opt_learning_rate = 0.005 #@param {type: "number"}

## aplicación de los parámetros elegidos

# cantidad de neuronas ocultas
##hidden_layers = [ num_inputs//5, num_inputs//20, num_inputs//100 ]
hidden_layers = []
for val in rna_cant_neuronas_capas_ocultas.split(','):
  val = val.strip()
  if val == "D":
    hidden_layers.append( "DropOut" )
  elif val == "BN":
    hidden_layers.append( "BatchNormalization" )
  elif val.isnumeric():
    hidden_layers.append( val )
  else:
    print("Capa ", val, "descartada!")

# chequea configuración de drop out
if rna_porc_capa_DropOut <= 0:
  rna_porc_capa_DropOut = 0.10
elif rna_porc_capa_DropOut > 0.9:
    rna_porc_capa_DropOut = 0.9


# define si el tipo de capa de salida es softmax( True )  o lineal ( False )
# esto implica también cambiar cómo se codifican los valores de las clases a usar
tipo_output_softMax = (rna_tipo_capa_salida[:7] == 'softmax')

# define la arquitectura de capas teniendo en cuenta la definición dada anteriomente
##input_img_Lay = Input(shape=(num_inputs,), name='input_img') # capa de entrada
input_img_Lay = tf.keras.layers.Input(shape=IMAGE_SHAPE, name='input_img') # capa de entrada
eachLay = input_img_Lay

# agrega capas de data augmentation si se usan
if len(daLayers_modelo)>0:
  for da_lay in daLayers_modelo:
    eachLay = da_lay(eachLay)

# agrega capa para ajuste de imágenes
eachLay = tf.keras.layers.Rescaling(1./255, name='slng_1/255')(eachLay)

#eachLay = tf.keras.layers.Conv2D(32, (3,3), activation=lineal_tipo_funcion, name='convo2')(eachLay)
#eachLay = tf.keras.layers.MaxPooling2D((2,2), name='pool2')(eachLay)
#eachLay = tf.keras.layers.Dropout(rna_porc_capa_DropOut, name='drop2')(eachLay)
#eachLay = tf.keras.layers.Conv2D(64, (3,3), activation=lineal_tipo_funcion, name='convo3')(eachLay)
#eachLay = tf.keras.layers.MaxPooling2D((2,2), name='pool3')(eachLay)

eachLay = tf.keras.layers.Flatten(name='flat')(eachLay)

# agrega capas ocultas
auxName = 'hidd_'
auxId = 1
for val_hid in hidden_layers:

  if val_hid == "DropOut":
    auxlayerName = "d_"+str(auxId)
    auxId = auxId + 1
    eachLay = tf.keras.layers.Dropout(rna_porc_capa_DropOut, name=auxlayerName)(eachLay)
  elif val_hid == "BatchNormalization":
    auxlayerName = "bn_"+str(auxId)
    auxId = auxId + 1
    eachLay = tf.keras.layers.BatchNormalization(name=auxlayerName)(eachLay)
  elif val_hid.isnumeric():
    # agrega la capa oculta
    auxlayerName = auxName+str(auxId)
    auxId = auxId + 1
    eachLay = tf.keras.layers.Dense(int(val_hid), activation=lineal_tipo_funcion, name=auxlayerName)(eachLay) # capas ocultas

# agrega capa de salida
if tipo_output_softMax:
    # se genera una capa softmax
    #eachLay = tf.keras.layers.Dropout(rna_porc_capa_DropOut, name='drop2')(eachLay) # se aagrega
    output_img_Lay = tf.keras.layers.Dense(units = len(dictMapeo), activation='softmax', name='output')(eachLay) # capa de salida
else:
    # se genera una capa lineal con una salida numérica
    output_img_Lay = tf.keras.layers.Dense(1, activation=None, name='output')(eachLay) # capa de salida


if opt_tipo == "Gradiente Decreciente":
  opt = keras.optimizers.SGD(learning_rate=opt_learning_rate)
elif opt_tipo == "Adam":
  opt = keras.optimizers.Adam(learning_rate=opt_learning_rate)
elif opt_tipo == "Adadelta":
  opt = keras.optimizers.Adadelta(learning_rate=opt_learning_rate)
elif opt_tipo == "Adagrad":
  opt = keras.optimizers.Adagrad(learning_rate=opt_learning_rate)
elif opt_tipo == "Adamax":
  opt = keras.optimizers.Adamax(learning_rate=opt_learning_rate)
elif opt_tipo == "Nadam":
  opt = keras.optimizers.Nadam(learning_rate=opt_learning_rate)
elif opt_tipo == "FTRL":
  opt = keras.optimizers.Ftrl(learning_rate=opt_learning_rate)
else:
  opt = keras.optimizers.Adam()

# genera el modelo RNA MLP Backpropagation
model = Model(input_img_Lay, output_img_Lay, name='RNA')
if tipo_output_softMax:
    # utiliza un loss de multiple clases
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
else:
    # utiliza un loss de valor numérico
    model.compile(optimizer=opt, loss='mse', metrics=['accuracy'])

print("Modelo creado con ", len(model.layers), " capas:")
model.summary()
print("\n")
plot_model(model, show_layer_names=True, show_shapes=True)
# Out:
# Modelo creado con  13  capas:
# Model: "RNA"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_img (InputLayer)      [(None, 32, 32, 3)]       0
#
#  slng_1/255 (Rescaling)      (None, 32, 32, 3)         0
#
#  convo1 (Conv2D)             (None, 30, 30, 16)        448
#
#  pool1 (MaxPooling2D)        (None, 15, 15, 16)        0
#
#  drop1 (Dropout)             (None, 15, 15, 16)        0
#
#  convo2 (Conv2D)             (None, 13, 13, 32)        4640
#
#  pool2 (MaxPooling2D)        (None, 6, 6, 32)          0
#
#  drop2 (Dropout)             (None, 6, 6, 32)          0
#
#  convo3 (Conv2D)             (None, 4, 4, 64)          18496
#
#  pool3 (MaxPooling2D)        (None, 2, 2, 64)          0
#
#  flat (Flatten)              (None, 256)               0
#
#  hidd_1 (Dense)              (None, 4096)              1052672
#
#  output (Dense)              (None, 2)                 8194
#
# =================================================================
# Total params: 1084450 (4.14 MB)
# Trainable params: 1084450 (4.14 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# 6) Entrenar el modelo de la RNA:

# %%
#@title Entrenar

cant_epocas_entrenamiento = 100 #@param {type:"integer"}
porcentaje_validacion = 0.1 #@param {type:"number"}

# cantidad de épocas del entrenamiento
cantEpocas = (1 if cant_epocas_entrenamiento<1 else cant_epocas_entrenamiento)

activar_corte_por_estabilidad_val_loss = False #@param {type:"boolean"}

# separa al azar usando muestreo al azar del 10%
# para tomar algunos como datos de validación
x_t, x_v, y_t, y_v = train_test_split(x_train,
                                       (y_trainEnc if tipo_output_softMax else y_train),
                                       test_size=porcentaje_validacion, shuffle=True)

print("\n> De los ", len(x_train), "ejemplos de entrenamiento: ")
print("            se usan ", len(x_t), "ejemplos para entrenar ")
print("            y ", len(x_v), "ejemplos para validar.")

print("\n\n>Comienza el Entrenamiento:")

if activar_corte_por_estabilidad_val_loss:
  # se agrega un callBack para que corte
  # si el error de validación no sigue bajando
  # y devuelva los mejores pesos obtenidos
  early_stopping_monitor = keras.callbacks.EarlyStopping(
      monitor='val_loss',
      min_delta=0.01,
      patience=20,
      verbose=1,
      mode='min',
      baseline=None,
      restore_best_weights=True,
      start_from_epoch=5
  )
  callbacksEntr = [early_stopping_monitor]
else:
  early_stopping_monitor = None
  callbacksEntr = []

# lleva a cabo el entrenamiento
history = model.fit(x_t, y_t,
          epochs = cantEpocas,
          validation_data=(x_v, y_v,),
          callbacks=callbacksEntr )

print("\n>Entrenamiento Finalizado.")
# Out:
# > De los  2837 ejemplos de entrenamiento:
#             se usan  2553 ejemplos para entrenar
#             y  284 ejemplos para validar.
#
#
# >Comienza el Entrenamiento:
# Epoch 1/300
# 80/80 [==============================] - 57s 8ms/step - loss: 0.7044 - accuracy: 0.5221 - val_loss: 0.6909 - val_accuracy: 0.5352
# Epoch 2/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.6899 - accuracy: 0.5437 - val_loss: 0.6911 - val_accuracy: 0.5352
# Epoch 3/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.6886 - accuracy: 0.5441 - val_loss: 0.6928 - val_accuracy: 0.5317
# Epoch 4/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.6352 - accuracy: 0.6342 - val_loss: 0.5792 - val_accuracy: 0.6937
# Epoch 5/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.5520 - accuracy: 0.7199 - val_loss: 0.5533 - val_accuracy: 0.7500
# Epoch 6/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.5045 - accuracy: 0.7615 - val_loss: 0.7219 - val_accuracy: 0.5493
# Epoch 7/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.5039 - accuracy: 0.7571 - val_loss: 0.4742 - val_accuracy: 0.7817
# Epoch 8/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.4730 - accuracy: 0.7814 - val_loss: 0.4744 - val_accuracy: 0.7570
# Epoch 9/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.4583 - accuracy: 0.7771 - val_loss: 0.4874 - val_accuracy: 0.7606
# Epoch 10/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.4523 - accuracy: 0.7881 - val_loss: 0.4447 - val_accuracy: 0.7817
# Epoch 11/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.4358 - accuracy: 0.7924 - val_loss: 0.4854 - val_accuracy: 0.7570
# Epoch 12/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.4537 - accuracy: 0.7850 - val_loss: 0.4851 - val_accuracy: 0.7535
# Epoch 13/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.4365 - accuracy: 0.7850 - val_loss: 0.4588 - val_accuracy: 0.7746
# Epoch 14/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.4355 - accuracy: 0.7885 - val_loss: 0.4502 - val_accuracy: 0.7676
# Epoch 15/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.4231 - accuracy: 0.7897 - val_loss: 0.4295 - val_accuracy: 0.7852
# Epoch 16/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.4079 - accuracy: 0.7963 - val_loss: 0.4379 - val_accuracy: 0.7570
# Epoch 17/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.4513 - accuracy: 0.7775 - val_loss: 0.4416 - val_accuracy: 0.7993
# Epoch 18/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.4187 - accuracy: 0.7916 - val_loss: 0.4253 - val_accuracy: 0.7746
# Epoch 19/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.4023 - accuracy: 0.8034 - val_loss: 0.4506 - val_accuracy: 0.7500
# Epoch 20/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.3991 - accuracy: 0.7967 - val_loss: 0.4332 - val_accuracy: 0.7535
# Epoch 21/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.4010 - accuracy: 0.8061 - val_loss: 0.4376 - val_accuracy: 0.7887
# Epoch 22/300
# 80/80 [==============================] - 1s 8ms/step - loss: 0.4123 - accuracy: 0.7908 - val_loss: 0.4443 - val_accuracy: 0.7817
# Epoch 23/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.4249 - accuracy: 0.7889 - val_loss: 0.4129 - val_accuracy: 0.7958
# Epoch 24/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.3870 - accuracy: 0.8053 - val_loss: 0.3946 - val_accuracy: 0.8063
# Epoch 25/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3800 - accuracy: 0.8116 - val_loss: 0.4708 - val_accuracy: 0.7570
# Epoch 26/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.4035 - accuracy: 0.7991 - val_loss: 0.4246 - val_accuracy: 0.8134
# Epoch 27/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.4281 - accuracy: 0.7881 - val_loss: 0.4388 - val_accuracy: 0.7923
# Epoch 28/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3864 - accuracy: 0.8159 - val_loss: 0.3987 - val_accuracy: 0.8028
# Epoch 29/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.4168 - accuracy: 0.7967 - val_loss: 0.3946 - val_accuracy: 0.8063
# Epoch 30/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3865 - accuracy: 0.8049 - val_loss: 0.4884 - val_accuracy: 0.7746
# Epoch 31/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3961 - accuracy: 0.8057 - val_loss: 0.4177 - val_accuracy: 0.7923
# Epoch 32/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3813 - accuracy: 0.8108 - val_loss: 0.3806 - val_accuracy: 0.8310
# Epoch 33/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3784 - accuracy: 0.8124 - val_loss: 0.4946 - val_accuracy: 0.7430
# Epoch 34/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3915 - accuracy: 0.7979 - val_loss: 0.3797 - val_accuracy: 0.8028
# Epoch 35/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3667 - accuracy: 0.8120 - val_loss: 0.3956 - val_accuracy: 0.7923
# Epoch 36/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3724 - accuracy: 0.8124 - val_loss: 0.4058 - val_accuracy: 0.7887
# Epoch 37/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3722 - accuracy: 0.8175 - val_loss: 0.3776 - val_accuracy: 0.8345
# Epoch 38/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3825 - accuracy: 0.8042 - val_loss: 0.3959 - val_accuracy: 0.8099
# Epoch 39/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3630 - accuracy: 0.8265 - val_loss: 0.3998 - val_accuracy: 0.7887
# Epoch 40/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3829 - accuracy: 0.8124 - val_loss: 0.3677 - val_accuracy: 0.8169
# Epoch 41/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3802 - accuracy: 0.8222 - val_loss: 0.4015 - val_accuracy: 0.8204
# Epoch 42/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3642 - accuracy: 0.8218 - val_loss: 0.3655 - val_accuracy: 0.8204
# Epoch 43/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3560 - accuracy: 0.8233 - val_loss: 0.4162 - val_accuracy: 0.7817
# Epoch 44/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3648 - accuracy: 0.8253 - val_loss: 0.4069 - val_accuracy: 0.7887
# Epoch 45/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3631 - accuracy: 0.8190 - val_loss: 0.4142 - val_accuracy: 0.8169
# Epoch 46/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3778 - accuracy: 0.8171 - val_loss: 0.4023 - val_accuracy: 0.7958
# Epoch 47/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3662 - accuracy: 0.8245 - val_loss: 0.3955 - val_accuracy: 0.7958
# Epoch 48/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3646 - accuracy: 0.8249 - val_loss: 0.4371 - val_accuracy: 0.7817
# Epoch 49/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.3724 - accuracy: 0.8300 - val_loss: 0.4532 - val_accuracy: 0.8204
# Epoch 50/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.3708 - accuracy: 0.8155 - val_loss: 0.4013 - val_accuracy: 0.7887
# Epoch 51/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.3597 - accuracy: 0.8241 - val_loss: 0.4126 - val_accuracy: 0.8028
# Epoch 52/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.3551 - accuracy: 0.8253 - val_loss: 0.3834 - val_accuracy: 0.8134
# Epoch 53/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.3568 - accuracy: 0.8269 - val_loss: 0.3872 - val_accuracy: 0.8169
# Epoch 54/300
# 80/80 [==============================] - 1s 8ms/step - loss: 0.3660 - accuracy: 0.8171 - val_loss: 0.3808 - val_accuracy: 0.8134
# Epoch 55/300
# 80/80 [==============================] - 1s 8ms/step - loss: 0.3536 - accuracy: 0.8320 - val_loss: 0.3979 - val_accuracy: 0.7887
# Epoch 56/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3502 - accuracy: 0.8296 - val_loss: 0.4148 - val_accuracy: 0.7887
# Epoch 57/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.3668 - accuracy: 0.8190 - val_loss: 0.3959 - val_accuracy: 0.8239
# Epoch 58/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3596 - accuracy: 0.8226 - val_loss: 0.4341 - val_accuracy: 0.7711
# Epoch 59/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.3368 - accuracy: 0.8367 - val_loss: 0.3815 - val_accuracy: 0.8134
# Epoch 60/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3620 - accuracy: 0.8198 - val_loss: 0.3907 - val_accuracy: 0.7852
# Epoch 61/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3477 - accuracy: 0.8327 - val_loss: 0.3725 - val_accuracy: 0.8204
# Epoch 62/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3543 - accuracy: 0.8296 - val_loss: 0.4724 - val_accuracy: 0.7500
# Epoch 63/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3612 - accuracy: 0.8218 - val_loss: 0.4118 - val_accuracy: 0.8063
# Epoch 64/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.3533 - accuracy: 0.8296 - val_loss: 0.3947 - val_accuracy: 0.8099
# Epoch 65/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3640 - accuracy: 0.8186 - val_loss: 0.4121 - val_accuracy: 0.8204
# Epoch 66/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3589 - accuracy: 0.8265 - val_loss: 0.4089 - val_accuracy: 0.7993
# Epoch 67/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3489 - accuracy: 0.8398 - val_loss: 0.3876 - val_accuracy: 0.8204
# Epoch 68/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3563 - accuracy: 0.8218 - val_loss: 0.4116 - val_accuracy: 0.7958
# Epoch 69/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3469 - accuracy: 0.8343 - val_loss: 0.3757 - val_accuracy: 0.8275
# Epoch 70/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3614 - accuracy: 0.8269 - val_loss: 0.3979 - val_accuracy: 0.7993
# Epoch 71/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3464 - accuracy: 0.8284 - val_loss: 0.4032 - val_accuracy: 0.8063
# Epoch 72/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3372 - accuracy: 0.8382 - val_loss: 0.3695 - val_accuracy: 0.7958
# Epoch 73/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3376 - accuracy: 0.8410 - val_loss: 0.4570 - val_accuracy: 0.8028
# Epoch 74/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3556 - accuracy: 0.8312 - val_loss: 0.3840 - val_accuracy: 0.8134
# Epoch 75/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3219 - accuracy: 0.8406 - val_loss: 0.3943 - val_accuracy: 0.7993
# Epoch 76/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.3535 - accuracy: 0.8324 - val_loss: 0.3634 - val_accuracy: 0.8275
# Epoch 77/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3541 - accuracy: 0.8218 - val_loss: 0.4566 - val_accuracy: 0.7852
# Epoch 78/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.3466 - accuracy: 0.8277 - val_loss: 0.4032 - val_accuracy: 0.8169
# Epoch 79/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.3662 - accuracy: 0.8214 - val_loss: 0.3823 - val_accuracy: 0.8204
# Epoch 80/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.3512 - accuracy: 0.8277 - val_loss: 0.3895 - val_accuracy: 0.8169
# Epoch 81/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.3351 - accuracy: 0.8433 - val_loss: 0.3943 - val_accuracy: 0.8134
# Epoch 82/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.3327 - accuracy: 0.8418 - val_loss: 0.3846 - val_accuracy: 0.8063
# Epoch 83/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.3401 - accuracy: 0.8414 - val_loss: 0.4099 - val_accuracy: 0.8134
# Epoch 84/300
# 80/80 [==============================] - 1s 8ms/step - loss: 0.3538 - accuracy: 0.8312 - val_loss: 0.4258 - val_accuracy: 0.7817
# Epoch 85/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.3443 - accuracy: 0.8351 - val_loss: 0.3584 - val_accuracy: 0.8239
# Epoch 86/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.3275 - accuracy: 0.8465 - val_loss: 0.3823 - val_accuracy: 0.7993
# Epoch 87/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3392 - accuracy: 0.8410 - val_loss: 0.3806 - val_accuracy: 0.8169
# Epoch 88/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.3416 - accuracy: 0.8351 - val_loss: 0.3759 - val_accuracy: 0.8099
# Epoch 89/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3324 - accuracy: 0.8484 - val_loss: 0.3802 - val_accuracy: 0.7993
# Epoch 90/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3383 - accuracy: 0.8398 - val_loss: 0.4321 - val_accuracy: 0.7958
# Epoch 91/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3276 - accuracy: 0.8406 - val_loss: 0.3947 - val_accuracy: 0.7958
# Epoch 92/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3299 - accuracy: 0.8488 - val_loss: 0.3594 - val_accuracy: 0.8204
# Epoch 93/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3243 - accuracy: 0.8402 - val_loss: 0.3670 - val_accuracy: 0.8134
# Epoch 94/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3403 - accuracy: 0.8304 - val_loss: 0.3739 - val_accuracy: 0.8134
# Epoch 95/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3363 - accuracy: 0.8378 - val_loss: 0.3805 - val_accuracy: 0.8063
# Epoch 96/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3289 - accuracy: 0.8453 - val_loss: 0.4530 - val_accuracy: 0.7782
# Epoch 97/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3574 - accuracy: 0.8241 - val_loss: 0.3848 - val_accuracy: 0.7993
# Epoch 98/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3369 - accuracy: 0.8374 - val_loss: 0.4187 - val_accuracy: 0.8169
# Epoch 99/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3444 - accuracy: 0.8351 - val_loss: 0.3833 - val_accuracy: 0.8275
# Epoch 100/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3309 - accuracy: 0.8378 - val_loss: 0.3933 - val_accuracy: 0.8134
# Epoch 101/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3337 - accuracy: 0.8386 - val_loss: 0.3979 - val_accuracy: 0.7993
# Epoch 102/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3541 - accuracy: 0.8296 - val_loss: 0.4090 - val_accuracy: 0.7852
# Epoch 103/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3304 - accuracy: 0.8363 - val_loss: 0.3723 - val_accuracy: 0.8134
# Epoch 104/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3179 - accuracy: 0.8496 - val_loss: 0.3624 - val_accuracy: 0.8239
# Epoch 105/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3396 - accuracy: 0.8277 - val_loss: 0.3952 - val_accuracy: 0.8204
# Epoch 106/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3377 - accuracy: 0.8418 - val_loss: 0.3749 - val_accuracy: 0.8169
# Epoch 107/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3195 - accuracy: 0.8468 - val_loss: 0.3682 - val_accuracy: 0.8380
# Epoch 108/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3179 - accuracy: 0.8433 - val_loss: 0.3512 - val_accuracy: 0.8204
# Epoch 109/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3268 - accuracy: 0.8433 - val_loss: 0.4056 - val_accuracy: 0.8028
# Epoch 110/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.3370 - accuracy: 0.8386 - val_loss: 0.3754 - val_accuracy: 0.8380
# Epoch 111/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.3362 - accuracy: 0.8433 - val_loss: 0.4129 - val_accuracy: 0.7746
# Epoch 112/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.3208 - accuracy: 0.8512 - val_loss: 0.3744 - val_accuracy: 0.8345
# Epoch 113/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.3157 - accuracy: 0.8523 - val_loss: 0.4278 - val_accuracy: 0.7887
# Epoch 114/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.3162 - accuracy: 0.8504 - val_loss: 0.3703 - val_accuracy: 0.8345
# Epoch 115/300
# 80/80 [==============================] - 1s 8ms/step - loss: 0.3259 - accuracy: 0.8449 - val_loss: 0.3824 - val_accuracy: 0.8063
# Epoch 116/300
# 80/80 [==============================] - 1s 9ms/step - loss: 0.3367 - accuracy: 0.8335 - val_loss: 0.3837 - val_accuracy: 0.7746
# Epoch 117/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.3167 - accuracy: 0.8551 - val_loss: 0.3850 - val_accuracy: 0.8239
# Epoch 118/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.3385 - accuracy: 0.8457 - val_loss: 0.3636 - val_accuracy: 0.8204
# Epoch 119/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.3194 - accuracy: 0.8465 - val_loss: 0.3878 - val_accuracy: 0.8134
# Epoch 120/300
# 80/80 [==============================] - 1s 8ms/step - loss: 0.3234 - accuracy: 0.8574 - val_loss: 0.3593 - val_accuracy: 0.8028
# Epoch 121/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.3259 - accuracy: 0.8515 - val_loss: 0.3803 - val_accuracy: 0.8028
# Epoch 122/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.3373 - accuracy: 0.8433 - val_loss: 0.4808 - val_accuracy: 0.7113
# Epoch 123/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.3265 - accuracy: 0.8429 - val_loss: 0.4116 - val_accuracy: 0.7958
# Epoch 124/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3121 - accuracy: 0.8508 - val_loss: 0.3786 - val_accuracy: 0.8239
# Epoch 125/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3194 - accuracy: 0.8508 - val_loss: 0.4250 - val_accuracy: 0.8099
# Epoch 126/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3074 - accuracy: 0.8582 - val_loss: 0.3814 - val_accuracy: 0.8169
# Epoch 127/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3208 - accuracy: 0.8519 - val_loss: 0.3660 - val_accuracy: 0.7887
# Epoch 128/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3142 - accuracy: 0.8472 - val_loss: 0.4059 - val_accuracy: 0.8134
# Epoch 129/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.3354 - accuracy: 0.8402 - val_loss: 0.4104 - val_accuracy: 0.7817
# Epoch 130/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3280 - accuracy: 0.8425 - val_loss: 0.3704 - val_accuracy: 0.8099
# Epoch 131/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3186 - accuracy: 0.8515 - val_loss: 0.3511 - val_accuracy: 0.8380
# Epoch 132/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3169 - accuracy: 0.8531 - val_loss: 0.3497 - val_accuracy: 0.8239
# Epoch 133/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3012 - accuracy: 0.8613 - val_loss: 0.3714 - val_accuracy: 0.8239
# Epoch 134/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3160 - accuracy: 0.8574 - val_loss: 0.4318 - val_accuracy: 0.7958
# Epoch 135/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3499 - accuracy: 0.8449 - val_loss: 0.3821 - val_accuracy: 0.8063
# Epoch 136/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3193 - accuracy: 0.8582 - val_loss: 0.3595 - val_accuracy: 0.8169
# Epoch 137/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.3301 - accuracy: 0.8555 - val_loss: 0.3938 - val_accuracy: 0.8099
# Epoch 138/300
# 80/80 [==============================] - 1s 6ms/step - loss: 0.3206 - accuracy: 0.8433 - val_loss: 0.4058 - val_accuracy: 0.7782
# Epoch 139/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.3219 - accuracy: 0.8437 - val_loss: 0.3510 - val_accuracy: 0.8275
# Epoch 140/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.3224 - accuracy: 0.8465 - val_loss: 0.3294 - val_accuracy: 0.8310
# Epoch 141/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.3247 - accuracy: 0.8484 - val_loss: 0.3532 - val_accuracy: 0.8169
# Epoch 142/300
# 80/80 [==============================] - 1s 8ms/step - loss: 0.3119 - accuracy: 0.8484 - val_loss: 0.3462 - val_accuracy: 0.8204
# Epoch 143/300
# 80/80 [==============================] - 1s 8ms/step - loss: 0.3050 - accuracy: 0.8551 - val_loss: 0.3486 - val_accuracy: 0.8204
# Epoch 144/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.3119 - accuracy: 0.8570 - val_loss: 0.3826 - val_accuracy: 0.8134
# Epoch 145/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3350 - accuracy: 0.8374 - val_loss: 0.4125 - val_accuracy: 0.8099
# Epoch 146/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3089 - accuracy: 0.8543 - val_loss: 0.4008 - val_accuracy: 0.7782
# Epoch 147/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3206 - accuracy: 0.8500 - val_loss: 0.3847 - val_accuracy: 0.7958
# Epoch 148/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3061 - accuracy: 0.8523 - val_loss: 0.3480 - val_accuracy: 0.7993
# Epoch 149/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3035 - accuracy: 0.8531 - val_loss: 0.3515 - val_accuracy: 0.8239
# Epoch 150/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3064 - accuracy: 0.8527 - val_loss: 0.3740 - val_accuracy: 0.7923
# Epoch 151/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3051 - accuracy: 0.8574 - val_loss: 0.3568 - val_accuracy: 0.8451
# Epoch 152/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3164 - accuracy: 0.8418 - val_loss: 0.4022 - val_accuracy: 0.8099
# Epoch 153/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3206 - accuracy: 0.8531 - val_loss: 0.3930 - val_accuracy: 0.8028
# Epoch 154/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3007 - accuracy: 0.8547 - val_loss: 0.3482 - val_accuracy: 0.7958
# Epoch 155/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3073 - accuracy: 0.8551 - val_loss: 0.4150 - val_accuracy: 0.8099
# Epoch 156/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.3231 - accuracy: 0.8308 - val_loss: 0.3844 - val_accuracy: 0.8063
# Epoch 157/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3141 - accuracy: 0.8535 - val_loss: 0.3939 - val_accuracy: 0.8063
# Epoch 158/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2970 - accuracy: 0.8566 - val_loss: 0.3627 - val_accuracy: 0.8239
# Epoch 159/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.3026 - accuracy: 0.8547 - val_loss: 0.3703 - val_accuracy: 0.8134
# Epoch 160/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3016 - accuracy: 0.8621 - val_loss: 0.4002 - val_accuracy: 0.8063
# Epoch 161/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3129 - accuracy: 0.8504 - val_loss: 0.3819 - val_accuracy: 0.8239
# Epoch 162/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3214 - accuracy: 0.8382 - val_loss: 0.4278 - val_accuracy: 0.7817
# Epoch 163/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3070 - accuracy: 0.8535 - val_loss: 0.3446 - val_accuracy: 0.8380
# Epoch 164/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3058 - accuracy: 0.8574 - val_loss: 0.3877 - val_accuracy: 0.8099
# Epoch 165/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3146 - accuracy: 0.8488 - val_loss: 0.3960 - val_accuracy: 0.7958
# Epoch 166/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3054 - accuracy: 0.8508 - val_loss: 0.3834 - val_accuracy: 0.8028
# Epoch 167/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2942 - accuracy: 0.8602 - val_loss: 0.3895 - val_accuracy: 0.8204
# Epoch 168/300
# 80/80 [==============================] - 1s 6ms/step - loss: 0.3029 - accuracy: 0.8602 - val_loss: 0.3938 - val_accuracy: 0.8063
# Epoch 169/300
# 80/80 [==============================] - 1s 6ms/step - loss: 0.3053 - accuracy: 0.8609 - val_loss: 0.3531 - val_accuracy: 0.8134
# Epoch 170/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.3135 - accuracy: 0.8523 - val_loss: 0.4142 - val_accuracy: 0.7852
# Epoch 171/300
# 80/80 [==============================] - 1s 6ms/step - loss: 0.3543 - accuracy: 0.8230 - val_loss: 0.3788 - val_accuracy: 0.8099
# Epoch 172/300
# 80/80 [==============================] - 1s 8ms/step - loss: 0.3014 - accuracy: 0.8590 - val_loss: 0.3885 - val_accuracy: 0.8275
# Epoch 173/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.3203 - accuracy: 0.8465 - val_loss: 0.3671 - val_accuracy: 0.8028
# Epoch 174/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.3026 - accuracy: 0.8551 - val_loss: 0.3586 - val_accuracy: 0.8239
# Epoch 175/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.2953 - accuracy: 0.8606 - val_loss: 0.3521 - val_accuracy: 0.8415
# Epoch 176/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3030 - accuracy: 0.8562 - val_loss: 0.3910 - val_accuracy: 0.8169
# Epoch 177/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2955 - accuracy: 0.8617 - val_loss: 0.3969 - val_accuracy: 0.8275
# Epoch 178/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.2936 - accuracy: 0.8641 - val_loss: 0.3948 - val_accuracy: 0.8380
# Epoch 179/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2887 - accuracy: 0.8629 - val_loss: 0.3699 - val_accuracy: 0.8063
# Epoch 180/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2954 - accuracy: 0.8656 - val_loss: 0.5232 - val_accuracy: 0.7676
# Epoch 181/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3525 - accuracy: 0.8261 - val_loss: 0.4335 - val_accuracy: 0.7887
# Epoch 182/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3053 - accuracy: 0.8496 - val_loss: 0.3676 - val_accuracy: 0.8028
# Epoch 183/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2935 - accuracy: 0.8637 - val_loss: 0.3755 - val_accuracy: 0.8134
# Epoch 184/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2897 - accuracy: 0.8660 - val_loss: 0.4023 - val_accuracy: 0.7817
# Epoch 185/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2916 - accuracy: 0.8566 - val_loss: 0.3901 - val_accuracy: 0.8099
# Epoch 186/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2842 - accuracy: 0.8582 - val_loss: 0.4445 - val_accuracy: 0.7676
# Epoch 187/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3035 - accuracy: 0.8582 - val_loss: 0.4059 - val_accuracy: 0.8345
# Epoch 188/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2950 - accuracy: 0.8653 - val_loss: 0.3839 - val_accuracy: 0.8239
# Epoch 189/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2985 - accuracy: 0.8641 - val_loss: 0.3926 - val_accuracy: 0.8275
# Epoch 190/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2879 - accuracy: 0.8629 - val_loss: 0.3968 - val_accuracy: 0.8063
# Epoch 191/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2827 - accuracy: 0.8664 - val_loss: 0.4167 - val_accuracy: 0.8204
# Epoch 192/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3115 - accuracy: 0.8531 - val_loss: 0.3826 - val_accuracy: 0.8310
# Epoch 193/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3155 - accuracy: 0.8543 - val_loss: 0.3835 - val_accuracy: 0.8275
# Epoch 194/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.3371 - accuracy: 0.8378 - val_loss: 0.3761 - val_accuracy: 0.8310
# Epoch 195/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2952 - accuracy: 0.8578 - val_loss: 0.4154 - val_accuracy: 0.7746
# Epoch 196/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.2930 - accuracy: 0.8594 - val_loss: 0.4038 - val_accuracy: 0.8063
# Epoch 197/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2921 - accuracy: 0.8582 - val_loss: 0.5055 - val_accuracy: 0.7817
# Epoch 198/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3055 - accuracy: 0.8531 - val_loss: 0.3894 - val_accuracy: 0.8345
# Epoch 199/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.3063 - accuracy: 0.8555 - val_loss: 0.3872 - val_accuracy: 0.8099
# Epoch 200/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.2837 - accuracy: 0.8766 - val_loss: 0.4126 - val_accuracy: 0.8239
# Epoch 201/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.3021 - accuracy: 0.8535 - val_loss: 0.4190 - val_accuracy: 0.8204
# Epoch 202/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.3229 - accuracy: 0.8468 - val_loss: 0.3816 - val_accuracy: 0.7993
# Epoch 203/300
# 80/80 [==============================] - 1s 8ms/step - loss: 0.3029 - accuracy: 0.8602 - val_loss: 0.3740 - val_accuracy: 0.8099
# Epoch 204/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.3041 - accuracy: 0.8684 - val_loss: 0.4138 - val_accuracy: 0.7923
# Epoch 205/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.3123 - accuracy: 0.8519 - val_loss: 0.3780 - val_accuracy: 0.8275
# Epoch 206/300
# 80/80 [==============================] - 1s 6ms/step - loss: 0.2922 - accuracy: 0.8547 - val_loss: 0.3884 - val_accuracy: 0.8099
# Epoch 207/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2905 - accuracy: 0.8692 - val_loss: 0.3974 - val_accuracy: 0.8239
# Epoch 208/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2976 - accuracy: 0.8668 - val_loss: 0.4261 - val_accuracy: 0.8028
# Epoch 209/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2822 - accuracy: 0.8641 - val_loss: 0.3971 - val_accuracy: 0.8134
# Epoch 210/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2893 - accuracy: 0.8633 - val_loss: 0.3811 - val_accuracy: 0.7993
# Epoch 211/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2946 - accuracy: 0.8582 - val_loss: 0.4036 - val_accuracy: 0.8415
# Epoch 212/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2883 - accuracy: 0.8617 - val_loss: 0.4370 - val_accuracy: 0.8028
# Epoch 213/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3123 - accuracy: 0.8476 - val_loss: 0.3849 - val_accuracy: 0.8134
# Epoch 214/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3044 - accuracy: 0.8531 - val_loss: 0.3733 - val_accuracy: 0.8134
# Epoch 215/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3166 - accuracy: 0.8527 - val_loss: 0.3970 - val_accuracy: 0.8345
# Epoch 216/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3141 - accuracy: 0.8566 - val_loss: 0.4229 - val_accuracy: 0.8169
# Epoch 217/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2886 - accuracy: 0.8582 - val_loss: 0.3908 - val_accuracy: 0.8134
# Epoch 218/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2970 - accuracy: 0.8602 - val_loss: 0.4408 - val_accuracy: 0.8099
# Epoch 219/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2830 - accuracy: 0.8629 - val_loss: 0.4068 - val_accuracy: 0.8063
# Epoch 220/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3077 - accuracy: 0.8598 - val_loss: 0.3697 - val_accuracy: 0.8204
# Epoch 221/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2951 - accuracy: 0.8633 - val_loss: 0.3879 - val_accuracy: 0.7852
# Epoch 222/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3078 - accuracy: 0.8519 - val_loss: 0.4849 - val_accuracy: 0.8239
# Epoch 223/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2986 - accuracy: 0.8637 - val_loss: 0.3872 - val_accuracy: 0.8204
# Epoch 224/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2900 - accuracy: 0.8609 - val_loss: 0.3863 - val_accuracy: 0.8134
# Epoch 225/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2965 - accuracy: 0.8555 - val_loss: 0.3958 - val_accuracy: 0.8063
# Epoch 226/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3158 - accuracy: 0.8523 - val_loss: 0.4048 - val_accuracy: 0.8134
# Epoch 227/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.2864 - accuracy: 0.8688 - val_loss: 0.3687 - val_accuracy: 0.8239
# Epoch 228/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2874 - accuracy: 0.8672 - val_loss: 0.3802 - val_accuracy: 0.8028
# Epoch 229/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2859 - accuracy: 0.8711 - val_loss: 0.3746 - val_accuracy: 0.8169
# Epoch 230/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.2927 - accuracy: 0.8613 - val_loss: 0.3919 - val_accuracy: 0.8275
# Epoch 231/300
# 80/80 [==============================] - 1s 6ms/step - loss: 0.2568 - accuracy: 0.8770 - val_loss: 0.3939 - val_accuracy: 0.8204
# Epoch 232/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.2927 - accuracy: 0.8653 - val_loss: 0.3821 - val_accuracy: 0.8310
# Epoch 233/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.2853 - accuracy: 0.8672 - val_loss: 0.4086 - val_accuracy: 0.8099
# Epoch 234/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.2967 - accuracy: 0.8586 - val_loss: 0.3675 - val_accuracy: 0.8063
# Epoch 235/300
# 80/80 [==============================] - 1s 8ms/step - loss: 0.2737 - accuracy: 0.8739 - val_loss: 0.3869 - val_accuracy: 0.8134
# Epoch 236/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.2866 - accuracy: 0.8613 - val_loss: 0.3858 - val_accuracy: 0.8169
# Epoch 237/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.2965 - accuracy: 0.8590 - val_loss: 0.3828 - val_accuracy: 0.7958
# Epoch 238/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2933 - accuracy: 0.8531 - val_loss: 0.4281 - val_accuracy: 0.8099
# Epoch 239/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2916 - accuracy: 0.8653 - val_loss: 0.3866 - val_accuracy: 0.7958
# Epoch 240/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2900 - accuracy: 0.8660 - val_loss: 0.4523 - val_accuracy: 0.8063
# Epoch 241/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2738 - accuracy: 0.8707 - val_loss: 0.4259 - val_accuracy: 0.8063
# Epoch 242/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.2707 - accuracy: 0.8797 - val_loss: 0.4208 - val_accuracy: 0.8028
# Epoch 243/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3014 - accuracy: 0.8602 - val_loss: 0.3863 - val_accuracy: 0.7993
# Epoch 244/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.2961 - accuracy: 0.8602 - val_loss: 0.3608 - val_accuracy: 0.8275
# Epoch 245/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2907 - accuracy: 0.8645 - val_loss: 0.3919 - val_accuracy: 0.8028
# Epoch 246/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2974 - accuracy: 0.8535 - val_loss: 0.3956 - val_accuracy: 0.8099
# Epoch 247/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2810 - accuracy: 0.8602 - val_loss: 0.3896 - val_accuracy: 0.7993
# Epoch 248/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3195 - accuracy: 0.8457 - val_loss: 0.4536 - val_accuracy: 0.8028
# Epoch 249/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2899 - accuracy: 0.8711 - val_loss: 0.4067 - val_accuracy: 0.7887
# Epoch 250/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2630 - accuracy: 0.8719 - val_loss: 0.4105 - val_accuracy: 0.8099
# Epoch 251/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2577 - accuracy: 0.8797 - val_loss: 0.3965 - val_accuracy: 0.8380
# Epoch 252/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2800 - accuracy: 0.8688 - val_loss: 0.3851 - val_accuracy: 0.8169
# Epoch 253/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.2808 - accuracy: 0.8715 - val_loss: 0.3942 - val_accuracy: 0.8063
# Epoch 254/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2726 - accuracy: 0.8754 - val_loss: 0.4049 - val_accuracy: 0.8169
# Epoch 255/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2782 - accuracy: 0.8735 - val_loss: 0.4049 - val_accuracy: 0.8099
# Epoch 256/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.2725 - accuracy: 0.8797 - val_loss: 0.4613 - val_accuracy: 0.8099
# Epoch 257/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2742 - accuracy: 0.8688 - val_loss: 0.4326 - val_accuracy: 0.8063
# Epoch 258/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2794 - accuracy: 0.8696 - val_loss: 0.4558 - val_accuracy: 0.7993
# Epoch 259/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3056 - accuracy: 0.8574 - val_loss: 0.4125 - val_accuracy: 0.8028
# Epoch 260/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2580 - accuracy: 0.8758 - val_loss: 0.3967 - val_accuracy: 0.8275
# Epoch 261/300
# 80/80 [==============================] - 1s 8ms/step - loss: 0.2936 - accuracy: 0.8656 - val_loss: 0.4256 - val_accuracy: 0.7958
# Epoch 262/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.2752 - accuracy: 0.8750 - val_loss: 0.3995 - val_accuracy: 0.8275
# Epoch 263/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.3049 - accuracy: 0.8508 - val_loss: 0.4042 - val_accuracy: 0.7923
# Epoch 264/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.2924 - accuracy: 0.8715 - val_loss: 0.3977 - val_accuracy: 0.8169
# Epoch 265/300
# 80/80 [==============================] - 1s 8ms/step - loss: 0.2759 - accuracy: 0.8743 - val_loss: 0.3895 - val_accuracy: 0.8169
# Epoch 266/300
# 80/80 [==============================] - 1s 8ms/step - loss: 0.2759 - accuracy: 0.8794 - val_loss: 0.3762 - val_accuracy: 0.8239
# Epoch 267/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.2865 - accuracy: 0.8739 - val_loss: 0.3972 - val_accuracy: 0.7993
# Epoch 268/300
# 80/80 [==============================] - 1s 8ms/step - loss: 0.2731 - accuracy: 0.8711 - val_loss: 0.3853 - val_accuracy: 0.8063
# Epoch 269/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.2570 - accuracy: 0.8825 - val_loss: 0.4176 - val_accuracy: 0.8063
# Epoch 270/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.2561 - accuracy: 0.8805 - val_loss: 0.3996 - val_accuracy: 0.8063
# Epoch 271/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2916 - accuracy: 0.8606 - val_loss: 0.3857 - val_accuracy: 0.7993
# Epoch 272/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.2647 - accuracy: 0.8739 - val_loss: 0.4123 - val_accuracy: 0.7852
# Epoch 273/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.3349 - accuracy: 0.8488 - val_loss: 0.4115 - val_accuracy: 0.7993
# Epoch 274/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2919 - accuracy: 0.8602 - val_loss: 0.4853 - val_accuracy: 0.7570
# Epoch 275/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.2914 - accuracy: 0.8645 - val_loss: 0.4441 - val_accuracy: 0.8028
# Epoch 276/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.2871 - accuracy: 0.8621 - val_loss: 0.4287 - val_accuracy: 0.8028
# Epoch 277/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.2660 - accuracy: 0.8703 - val_loss: 0.4239 - val_accuracy: 0.8169
# Epoch 278/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2701 - accuracy: 0.8797 - val_loss: 0.4160 - val_accuracy: 0.8063
# Epoch 279/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.2814 - accuracy: 0.8696 - val_loss: 0.4074 - val_accuracy: 0.7817
# Epoch 280/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.2751 - accuracy: 0.8715 - val_loss: 0.3894 - val_accuracy: 0.8310
# Epoch 281/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2899 - accuracy: 0.8645 - val_loss: 0.4018 - val_accuracy: 0.8204
# Epoch 282/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2704 - accuracy: 0.8778 - val_loss: 0.4007 - val_accuracy: 0.8063
# Epoch 283/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2989 - accuracy: 0.8617 - val_loss: 0.4225 - val_accuracy: 0.8204
# Epoch 284/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2740 - accuracy: 0.8766 - val_loss: 0.4000 - val_accuracy: 0.8134
# Epoch 285/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.2594 - accuracy: 0.8844 - val_loss: 0.4195 - val_accuracy: 0.8028
# Epoch 286/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2621 - accuracy: 0.8880 - val_loss: 0.4294 - val_accuracy: 0.8169
# Epoch 287/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.2871 - accuracy: 0.8754 - val_loss: 0.3934 - val_accuracy: 0.8134
# Epoch 288/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2711 - accuracy: 0.8782 - val_loss: 0.3967 - val_accuracy: 0.8275
# Epoch 289/300
# 80/80 [==============================] - 0s 6ms/step - loss: 0.2601 - accuracy: 0.8813 - val_loss: 0.4143 - val_accuracy: 0.8169
# Epoch 290/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.2829 - accuracy: 0.8778 - val_loss: 0.4244 - val_accuracy: 0.8169
# Epoch 291/300
# 80/80 [==============================] - 1s 8ms/step - loss: 0.2693 - accuracy: 0.8739 - val_loss: 0.4065 - val_accuracy: 0.8134
# Epoch 292/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.2717 - accuracy: 0.8688 - val_loss: 0.3927 - val_accuracy: 0.8239
# Epoch 293/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.2685 - accuracy: 0.8817 - val_loss: 0.4279 - val_accuracy: 0.7958
# Epoch 294/300
# 80/80 [==============================] - 1s 8ms/step - loss: 0.2647 - accuracy: 0.8825 - val_loss: 0.4754 - val_accuracy: 0.7817
# Epoch 295/300
# 80/80 [==============================] - 1s 8ms/step - loss: 0.2925 - accuracy: 0.8641 - val_loss: 0.4555 - val_accuracy: 0.8169
# Epoch 296/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.2581 - accuracy: 0.8817 - val_loss: 0.4270 - val_accuracy: 0.7887
# Epoch 297/300
# 80/80 [==============================] - 1s 7ms/step - loss: 0.2571 - accuracy: 0.8841 - val_loss: 0.4195 - val_accuracy: 0.8204
# Epoch 298/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2495 - accuracy: 0.8797 - val_loss: 0.4185 - val_accuracy: 0.7993
# Epoch 299/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3408 - accuracy: 0.8500 - val_loss: 0.3972 - val_accuracy: 0.8028
# Epoch 300/300
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2898 - accuracy: 0.8719 - val_loss: 0.4171 - val_accuracy: 0.7887
#
# >Entrenamiento Finalizado.

# %%
#@title Mostrar Gráficos del Entrenamiento
plt.figure(figsize=(15,8))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Gráfico del Error del Entrenamiento')
plt.ylabel('')
plt.xlabel('epoch')
plt.legend(['entrenamiento', 'validación'], loc='upper left')
plt.show()

plt.figure(figsize=(15,8))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Gráfico de la Exactitud del Entrenamiento')
plt.ylabel('')
plt.xlabel('epoch')
plt.legend(['entrenamiento', 'validación'], loc='upper left')
plt.show()

# %%
#@title Evaluar red entrenada con datos de entrenamiento


# explicación y fuente de GradCAM en:
#   https://medium.com/analytics-vidhya/visualizing-activation-heatmaps-using-tensorflow-5bdba018f759
def prepareGradCAM(model, last_conv_layer_name):
  # genera sub-modelo desde capa de entrada a última capa convultional
  last_conv_layer = model.get_layer(last_conv_layer_name)
  subModel = tf.keras.models.Model([model.inputs], [model.output, last_conv_layer.output])
  return subModel

def aplicarGradCAM(subModel, last_conv_layer_shape, imgOrig, intensity=0.5, res=250):
  # prepara la imagen a procesar
  img = copy.deepcopy(imgOrig)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)
  # genera el heatmap
  with tf.GradientTape() as tape:
    model_out, last_conv_layer = subModel(x)
    class_out = model_out[:, np.argmax(model_out[0])]
    grads = tape.gradient(class_out, last_conv_layer)
    pooled_grads = K.mean(grads, axis=(0, 1, 2))
  heatmap = tf.reduce_mean(tf.multiply(pooled_grads, last_conv_layer), axis=-1)
  heatmap = np.maximum(heatmap, 0)
  heatmap /= np.max(heatmap)
  heatmap = heatmap.reshape(last_conv_layer_shape) # (8, 8))
  # aplica el heatmap
  imgHM = copy.deepcopy(imgOrig)
  heatmap = cv2.resize(heatmap, (imgHM.shape[1], imgHM.shape[0]))
  heatmap = cv2.applyColorMap(np.uint8(255*heatmap), cv2.COLORMAP_JET)
  imgHM = heatmap * intensity + imgHM
  # devuelve imagen con HeatMap
  return imgHM

# función auxiliar para probar el modelo entrenado en detalle
def probarModelo(x, y, clases_map, tipo_output_softMax, umbralClas=50.0, mostrarGradCAM=False, rtdo="TODOS", cantMostrar="TODAS", claseFiltrar=None):

    # determina clase a filtrar
    if (claseFiltrar is None) or (claseFiltrar == "-"):
          clFiltrarID = None
          mostrarImagenes = False
    elif (claseFiltrar == "TODOS"):
          clFiltrarID = None
          mostrarImagenes = True
    else:
          clFiltrarID = dictMapeo[claseFiltrar]
          mostrarImagenes = True
    if umbralClas <= 0.0:
      umbralClas = 0.1
    elif umbralClas >= 100.0:
      umbralClas = 99.0
    else:
      umbralClas = umbralClas/100.0

    # determina tipo de resultado a mostrar
    if rtdo == "Clasificación Incorrecta":
      tipoRes = -1
    elif rtdo == "Clasificación Correcta":
      tipoRes = 1
    else:
      tipoRes = 0


    if mostrarGradCAM:
      # genera submodelo
      subModel = prepareGradCAM(model, last_conv_layer_name)
      # si muestra GradCAM también muestra imagen original
      mostrarImagenes = True

    # determina cantidad a mostrar
    if (cantMostrar == "TODAS"):
      cantMostrar = len(x)
    elif (cantMostrar <= 0):
      cantMostrar = 0
      mostrarImagenes = False

    # procesa las imágenes de prueba con el modelo
    predClass = model.predict(x, verbose=0)

    # lista auxiliar para mostrar
    imgsParaMostrar = []

    # muestra los resultados con las imágenes
    classPreds = []
    classReal = []
    for i in range(len(x)):

        # asigna el nombre de la clase real
        clReal = clases_map[ y[i] ]

        # determina la clase predecida
        if tipo_output_softMax:
            ## determina clase predecida de acuerdo a la que tiene mayor valor
            idclPred = int( np.argmax(predClass[i], axis=0) )
            idclPredRnd = idclPred
        else:
            ## determina clase predecida de acuerdo al umbral de clasificación
            idclPred = predClass[i][0]
            idclPredRnd = int(idclPred)
            if (idclPred - idclPredRnd)>umbralClas and (idclPredRnd+1)<len(clases_map):
                  idclPredRnd = idclPredRnd + 1

        # asigna el nombre de la clase predecida
        if idclPredRnd<0 or idclPredRnd>=len(clases_map):
            clPred = "CLASE " + str(idclPredRnd) + " INVÁLIDA!"
        else:
            clPred = clases_map[ idclPredRnd ]

        # agrega a vevtores auxiliares
        classReal.append( clReal )
        classPreds.append( clPred )
        resClasOK = (clReal==clPred)

        if mostrarImagenes:

          # determina si filtra por clase
          if (clFiltrarID is None) or (clFiltrarID == y[i]):

            # filtra por tipo de resultado
            if (tipoRes==0) or \
              ((tipoRes > 0) and resClasOK) or\
              ((tipoRes < 0) and not(resClasOK)):
                # el titulo par aponer en la imagen
                strTitulo = 'Real: ' + str(clReal) + ' / Modelo: ' + str(clPred)
                if not resClasOK:
                  strTitulo = strTitulo + "!"
                #strTitulo = strTitulo + clPred + ' (' + str( idclPred ) +')'

                # agrega para mostrar
                imgsParaMostrar.append( [strTitulo, x[i] ] )


    # cierra la imagen
    if mostrarImagenes and (cantMostrar>0) and (len(imgsParaMostrar)>0):
      print("\n>Detalle: ")

      if cantMostrar >= len(imgsParaMostrar):
        # muestra todas
        eligeImAlAzar = False
        cantMostrar = len(imgsParaMostrar)
      else:
        # muestra al azar
        eligeImAlAzar = True

      # prepara para mostrar imagenes
      if mostrarGradCAM:
        nCols = 2
        nRows = cantMostrar
        plt.figure(figsize=(5, 3*nRows))
      else:
        nCols = 3
        nRows = cantMostrar // nCols
        if (nRows*nCols) < cantMostrar:
          nRows = nRows + 1
        plt.figure(figsize=(10, 3*nRows))
      posImagen = 1

      for i in range(cantMostrar):
            # elige al azar o no para mostrar
            if eligeImAlAzar:
              posIm = random.randint(1, len(imgsParaMostrar))-1
            else:
              if i >= len(imgsParaMostrar):
                break
              else:
                posIm = i
            # determina datos a mostrar
            im = imgsParaMostrar[posIm][1]
            tit = imgsParaMostrar[posIm][0]

            # muestra la imagen
            ax = plt.subplot(nRows, nCols, posImagen)
            plot_image( im )
            plt.title( tit, fontsize=9 )
            posImagen = posImagen + 1

            # muestra resultado aplicar GRADCAM
            if mostrarGradCAM:
              imgGradCAM = aplicarGradCAM(subModel, last_conv_layer_shape, im)
              ax = plt.subplot(nRows, nCols, posImagen)
              plot_image( imgGradCAM )
              posImagen = posImagen + 1

            # saca elemento de la lista para no elegirlo al azar de nuevo
            if eligeImAlAzar:
              if len(imgsParaMostrar) > posIm:
                imgsParaMostrar.pop( posIm )

      #plt.tight_layout()
      fig = plt.gcf()
      plt.show()
      plt.close(fig)

    # muestra reporte de clasificación
    print("\n Reporte de Clasificación: ")
    print(classification_report(classReal, classPreds))

    # muestra matriz de confusion
    print('\nMatriz de Confusión ( real / modelo ): ')
    cm = confusion_matrix(classReal, classPreds, labels=clases_map)
    cmtx = pd.DataFrame(
        cm,
        index=['r:{:}'.format(x) for x in clases_map],
        columns=['m:{:}'.format(x) for x in clases_map]
      )
    cmtx.sort_index(axis=0, inplace=True)
    cmtx.sort_index(axis=1, inplace=True)
    print(cmtx)
    print("\n")


# genera toda la interface para evaluar modeo DAE
def crearUI_evaluarModelo(clDefecto, clases, ruidoPorDefecto, funcionCambiaSeleccion):

  # auxiliar para que muestre bien la descripción
  style_3D = {'description_width': 'initial'}
  childrenList = []

  slider_umbral = widgets.FloatSlider(
      value=50,
      min=0,
      max=100.0,
      step=1.0,
      description='Umbral de Clasificación: ',
      disabled=False,
      continuous_update=False,
      orientation='horizontal',
      readout=True,
      style=style_3D,
      readout_format='.1f',
  )
  if not tipo_output_softMax:
    childrenList.append( slider_umbral )

  # prepara combo para filtrar por clase
  seleccion_CLASES = ["-", "TODOS"]
  seleccion_CLASES.extend( clases )
  seleccion_CLASES.sort()
  combo_clase = widgets.Dropdown(
      options = seleccion_CLASES,
      value = clDefecto,
      description = 'Filtrar por clase:',
      style=style_3D,
      disabled = False,
  )
  childrenList.append( combo_clase )

  # prepara combo para filtrar por resultado
  selecc_resutado = [ "TODOS", "Clasificación Incorrecta", "Clasificación Correcta" ]
  combo_resultado = widgets.Dropdown(
      options = selecc_resutado,
      value = selecc_resutado[0],
      description = 'Filtrar por resultado:',
      style=style_3D,
      disabled = False,
  )
  childrenList.append( combo_resultado )

  # prepara combo para filtrar por cantidad
  selecc_cantidad = [ 3 ]
  selecc_cantidad.extend( range(6, 151, 9) )
  selecc_cantidad.append( "TODAS" )
  combo_cantidad = widgets.Dropdown(
      options = selecc_cantidad,
      value = 6,
      description = 'Mostrar N imágenes al azar:',
      style=style_3D,
      disabled = False,
  )
  childrenList.append( combo_cantidad )

  mostrar_HeatMap_de_GradCAM = widgets.Checkbox(
        value=False,
        description='Mostrar HeatMap de GradCAM',
        disabled=False
    )
  #childrenList.append( mostrar_HeatMap_de_GradCAM )


  prueba_ui = widgets.GridBox(children=childrenList,
          layout=Layout(width='100%')
        )
  out_prueba = widgets.interactive_output(funcionCambiaSeleccion, {'cant':combo_cantidad, 'rtdo': combo_resultado,'cl':combo_clase, 'h':mostrar_HeatMap_de_GradCAM, 'umbralClas':slider_umbral})

  return prueba_ui, out_prueba

# función para filtrar por clase
def cambiaSeleccion_clase_evaluar_imEntrenamiento(cant, rtdo, cl, h, umbralClas):

    # prueba con los datos de entrenamiento
    print("\n\n*** Resultados con datos de Entrenamiento: ")
    probarModelo(x_train, y_train, clases_map, tipo_output_softMax, umbralClas, h, rtdo, cant, cl)

# muestra la interface
ev_entrenamiento_ui, ev_entrenamiento_out = crearUI_evaluarModelo( "-", clases_map, 0.0, cambiaSeleccion_clase_evaluar_imEntrenamiento)
display(ev_entrenamiento_ui, ev_entrenamiento_out)
# Out:
# GridBox(children=(Dropdown(description='Filtrar por clase:', options=('-', 'TODOS', 'benign', 'malignant'), st…
# Output()

# %%
#@title Evaluar red entrenada con datos de prueba

# función para filtrar por clase
def cambiaSeleccion_clase_evaluar_imEntrenamiento(cant, rtdo, cl, h, umbralClas):

  # prueba con los datos de prueba
  print("\n\n*** Resultados con datos de Prueba: ")
  probarModelo(x_test, y_test, clases_map, tipo_output_softMax, umbralClas, h, rtdo, cant, cl)

# muestra la interface
ev_entrenamiento_ui, ev_entrenamiento_out = crearUI_evaluarModelo( "-", clases_map, 0.0, cambiaSeleccion_clase_evaluar_imEntrenamiento)
display(ev_entrenamiento_ui, ev_entrenamiento_out)
# Out:
# GridBox(children=(Dropdown(description='Filtrar por clase:', options=('-', 'TODOS', 'benign', 'malignant'), st…
# Output()
